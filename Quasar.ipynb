# %% [markdown]
# # Test for Quasar Measurement

# %% [markdown]
# - SDSS http://skyserver.sdss.org/dr16/en/tools/search/sql.aspx
# - https://astroquery.readthedocs.io/en/v0.1-0/_generated/astroquery.sdss.core.SDSS.html

# %% [markdown]
# ## Import APT data

# %%
import pandas as pd

# %%
apt3095 = pd.read_csv("{0}/{0}.csv".format('R3095'))
apt3095
# Out:
#       Number  ApertureRA  ApertureDec  CentroidRA  CentroidDec  ApertureX  \
# 0          1  226.407248    23.197118  226.409309    23.195850        469
# 1          2  225.642400    22.326898  225.642667    22.327433       3370
# 2          3  226.298662    23.083436  226.297270    23.084135        861
# 3          4  226.044715    22.788115  226.044178    22.788283       1837
# 4          5  225.784547    22.489521  225.784083    22.489515       2829
# ...      ...         ...          ...         ...          ...        ...
# 2865    2866  224.681675    23.566256  224.682047    23.565934       2295
# 2866    2867  225.217737    24.184697  225.218182    24.183452        250
# 2867    2868  224.718675    23.610343  224.717843    23.611270       2151
# 2868    2869  224.912982    23.835366  224.911634    23.837680       1408
# 2869    2870  224.592892    23.465172  224.598652    23.462128       2631
#
#       ApertureY  CentroidX  CentroidY  CentroidFlag  ...  ApertureMinorRadius  \
# 0            12    468.446      6.078             1  ...                    5
# 1            21   3368.522     21.370             1  ...                    5
# 2            28    861.685     31.743             1  ...                    5
# 3            19   1837.470     20.278             1  ...                    5
# 4            19   2829.710     19.861             1  ...                    5
# ...         ...        ...        ...           ...  ...                  ...
# 2865       3826   2295.103   3824.789             1  ...                    5
# 2866       3828    251.863   3825.166             1  ...                    5
# 2867       3828   2150.350   3831.041             1  ...                    5
# 2868       3829   1405.301   3835.232             1  ...                    5
# 2869       3829   2628.675   3813.368             1  ...                    5
#
#       ApertureRotationAngle  SkyRadiusInner SkyRadiusOuter  ApertureNumPixels  \
# 0                         0               8             15              79.04
# 1                         0               8             15              79.04
# 2                         0               8             15              79.04
# 3                         0               8             15              79.04
# 4                         0               8             15              79.04
# ...                     ...             ...            ...                ...
# 2865                      0               8             15              79.04
# 2866                      0               8             15              79.04
# 2867                      0               8             15              79.04
# 2868                      0               8             15              76.84
# 2869                      0               8             15              79.04
#
#       ApertureNumRejected  SkyNumPixels RadialProfileFWHM  Flags  \
# 0                     0.0           331             11.16      0
# 1                     0.0           514             11.99      0
# 2                     0.0           507              7.59      0
# 3                     0.0           501              3.92      0
# 4                     0.0           514             20.53      0
# ...                   ...           ...               ...    ...
# 2865                  0.0           511             13.54      0
# 2866                  0.0           511              5.68      0
# 2867                  0.0           401              4.05      0
# 2868                  0.0           324              8.83      0
# 2869                  0.0           512             85.61      0
#
#                                                   Image
# 0     /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 1     /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 2     /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 3     /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 4     /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# ...                                                 ...
# 2865  /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 2866  /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 2867  /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 2868  /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
# 2869  /Users/Lyy/Desktop/Uchi_Y2S3/_Yerkes/1915_plat...
#
# [2870 rows x 38 columns]

# %% [markdown]
# ## Get data from SDSS

# %%
from astroquery.sdss import SDSS
from astropy import coordinates as coords
from astropy import units as u
import matplotlib.pyplot as plt

# %%
pos = coords.SkyCoord(apt3095['CentroidRA'].mean(), apt3095['CentroidDec'].mean(), frame='icrs', unit='deg')

# %%
#all sources with spectrum (so they have the "class" par)
xid_QSO = SDSS.query_region(pos, radius = 70.0 * u.arcmin, spectro = True, fields = ['ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'class']) #'modelmagerr_u', etc
QSO3095 = xid_QSO.to_pandas()
#all sources with or withought spectrum
xid_cal = SDSS.query_region(pos, radius = 70.0 * u.arcmin, spectro = False, fields = ['ra', 'dec', 'u', 'g', 'r', 'i', 'z']) 
cal3095 = xid_cal.to_pandas()
#combine these two because there is a bug if we include "class" par in above
SDSS3095 = pd.merge(cal3095, QSO3095,  how='left', left_on=['ra','dec', 'u', 'g', 'r', 'i', 'z'], right_on = ['ra','dec', 'u', 'g', 'r', 'i', 'z'])
# Out:
# /Users/olina/anaconda3/lib/python3.7/site-packages/astroquery/sdss/core.py:865: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   comments='#'))

# %%
plt.scatter(SDSS3095['ra'], SDSS3095['dec'], alpha = 0.3)
plt.scatter(apt3095['CentroidRA'], apt3095['CentroidDec'], alpha = 0.3)
plt.scatter(SDSS3095[SDSS3095['class'] == b'QSO'] ['ra'], SDSS3095[SDSS3095['class'] == b'QSO'] ['dec'])

# %% [markdown]
# ## Match tables
# - Correct for proper motion?

# %%
import scipy
from scipy.spatial import distance
import numpy as np

# %%
def match(cal, apt):
    df = pd.DataFrame(columns=['ra', 'dec', 'u', 'g','r','i', 'z', 'class', 'CentroidRA','CentroidDec','Magnitude','diff'])
    dist = scipy.spatial.distance.cdist(apt[['CentroidRA', 'CentroidDec']], cal[['ra', 'dec']])
    min_dist = np.argmin(dist, axis=1)

    m = 0
    while m < len(apt):
        n = min_dist[m]
        df = df.append({'ra': cal['ra'][n], 'dec': cal['dec'][n], 'u': cal['u'][n], 'g': cal['g'][n], \
                        'r': cal['r'][n], 'i': cal['i'][n], 'z': cal['z'][n], 'class': cal['class'][n],\
                        'CentroidRA': apt['CentroidRA'][m],'CentroidDec': apt['CentroidDec'][m],\
                        'Magnitude': apt['Magnitude'][m],\
                        'diff': dist[m][n]
                       }, ignore_index=True)
        m += 1
    df = df.sort_values('diff').drop_duplicates('ra')
    df = df.sort_values('diff').drop_duplicates('CentroidRA')
    df = df.reset_index(drop=True) 
    return df
    #df['del_ra'] = (df['CentroidRA'] - df['ra']) * 3600 #degree -> arcsec
    #df['del_dec'] = (df['CentroidDec'] - df['dec']) * 3600 
    #export_csv = df.to_csv(MY_PATH + file + '/' + file + "_match.csv", index = None, header=True)
    #print("Matching finished.")

# %%
df3095 = match(SDSS3095, apt3095)

# %% [markdown]
# ## Check matches

# %% [markdown]
# - Remove mismatches

# %%
a = plt.hist(df3095['diff'], bins = 40)
print("Number of potential matches:", len(df3095))
# Out:
# Number of potential matches: 2504

# %%
df = df3095[df3095['diff'] <= 0.001].copy()
df = df[(df['u'] > 0) & (df['g'] > 0)]
df.dropna(subset=['ra', 'dec', 'u', 'g','r','i', 'z', 'CentroidRA','CentroidDec','Magnitude','diff'], inplace=True)

# %%
a = plt.hist(df['diff'])
print("Number of matches", len(df))
# Out:
# Number of matches 1318

# %% [markdown]
# - Check magnitude

# %%
plt.scatter(df['g'], df['Magnitude'])

# %%
df['pg'] = df['g']+0.3*(df['u']-df['g'])-0.45

# %%
#plt.figure(figsize = (15,10))
plt.scatter(df['pg'], df['Magnitude'])
plt.scatter(df[df['class'] == b'QSO']['pg'], df[df['class'] == b'QSO']['Magnitude'])

# %%
plt.scatter(df['ra'], df['dec'], c = df['Magnitude'] )

# %% [markdown]
# ## fit regression and see the color difference
# - https://scipy-cookbook.readthedocs.io/items/robust_regression.html

# %%
x = df['Magnitude']
y = df['pg']
p = np.poly1d(np.polyfit(x, y, 3))

# %%
testmag = np.arange(df['Magnitude'].min(), df['Magnitude'].max(), 0.01)
testpg = p(testmag)

# %%
plt.scatter(df['Magnitude'], df['pg'])
plt.scatter(testmag, testpg)

# %%
df['pg_pred'] = p(df['Magnitude'])
df['diff_mag'] = df['pg_pred'] - df['pg']

# %%
plt.scatter(df['ra'], df['dec'], c = df['diff_mag'], cmap = 'Greens', s = 7)

# %%
plt.scatter(df['ra'], df['diff_mag'])

# %%
plt.scatter(df['dec'], df['diff_mag'])

# %%
plt.scatter(df['Magnitude'], df['diff_mag'])

# %%
#linear regression on mag?
# import statsmodels.api as sm
# df_ = df_.dropna(subset=['u', 'g','r','i', 'z', 'Magnitude'])

# X = df_[['u', 'g', 'r', 'i', 'z']]
# y = df_['Magnitude']
# model = sm.OLS(y, X).fit()
# predictions = model.predict(X)
# model.summary()

# %%
# df_['cor_mag'] = predictions

# plt.scatter(df_['cor_mag'], df_['Magnitude'])
# plt.scatter(df_['cor_mag'], df_['g'])

# %% [markdown]
# ## Identify QSO

# %%
df_['QSO'] = (df_.ra.isin(qso.ra) & df_.dec.isin(qso.dec))

# %%
df_qso = df_[df_['QSO'] == True].copy()
df_qso
# Out:
#               ra        dec         u         g         r         i         z  \
# 71    258.822909  43.686418  19.27667  18.95424  18.87252  18.87396  18.71936
# 1330  257.855105  43.869076  19.03108  19.11633  19.14460  18.64607  18.69771
#
#       CentroidRA  CentroidDec  Magnitude      diff         pg   QSO
# 71    258.822886    43.686486     9.5694  0.000072  18.600969  True
# 1330  257.854670    43.868875    10.4625  0.000479  18.640755  True

# %%
list(df_[df_['QSO'] == True].index)
# Out:
# [71, 1330]

# %%
plt.figure(figsize = (15,10))
plt.scatter(df_['Magnitude'], df_['pg'], color = 'black', s = 15, alpha = 0.7)
plt.scatter(df_qso['Magnitude'], df_qso['pg'], color = 'red', s = 30)
plt.title("Magnitude for Plate R3107")
plt.xlabel("APT mag")
plt.ylabel("pg")
# Out:
# Text(0, 0.5, 'pg')

# %%
plt.figure(figsize = (15,10))
plt.scatter(df_['ra'], df_['dec'], color = 'black', s = 15, alpha = 0.7)
plt.scatter(df_qso['ra'], df_qso['dec'], color = 'red', s = 30)
plt.title("Position for Plate R3107")
plt.xlabel("RA")
plt.ylabel("Dec")
# Out:
# Text(0, 0.5, 'Dec')

# %% [markdown]
# ## Pick calibration stars

# %%
#qso1
qso1_ra = df_qso.iloc[0]['ra']
qso1_dec = df_qso.iloc[0]['dec']
qso1_pg = df_qso.iloc[0]['pg']
qso1_mag = df_qso.iloc[0]['Magnitude']

# %%
df_cal = df_[(df_['ra'] <= qso1_ra + 0.2)&(df_['ra'] >= qso1_ra - 0.2)\
            &(df_['dec'] <= qso1_dec + 0.2)&(df_['dec'] >= qso1_dec - 0.2)
            &(df_['pg'] <= qso1_pg + 1)&(df_['pg'] >= qso1_pg - 2)].copy()
df_cal = df_cal.dropna(subset=['pg', 'Magnitude'])
len(df_cal)
# Out:
# 145

# %%
plt.figure(figsize = (10,10))
plt.scatter(df_cal['Magnitude'], df_cal['pg'], color = 'black', s = 15, alpha = 0.7)
plt.scatter([df_qso.iloc[0]['Magnitude']], [df_qso.iloc[0]['pg']], color = 'red')
plt.title("Magnitude for Plate R3107")
plt.xlabel("APT mag")
plt.ylabel("pg")
# Out:
# Text(0, 0.5, 'pg')

# %%
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import abline_plot

X = df_cal['Magnitude']
X = sm.add_constant(X)
y = df_cal['pg']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d6aad5716362> in <module>
#       2 from statsmodels.graphics.regressionplots import abline_plot
#       3
# ----> 4 X = df_cal['Magnitude']
#       5 X = sm.add_constant(X)
#       6 y = df_cal['pg']
#
# NameError: name 'df_cal' is not defined

# %%
fig = abline_plot(model_results = model, color = 'black')
ax = fig.axes[0]
ax.scatter(df_cal['Magnitude'], df_cal['pg'])
ax.scatter([qso1_mag], [qso1_pg], color = 'red')

plt.title("Linear fit for calibration stars Plate R3107")
plt.xlabel("APT mag")
plt.ylabel("pg")
# Out:
# Text(20.625, 0.5, 'pg')

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, "Magnitude", fig=fig)

# %%
plt.scatter(df_cal['Magnitude'], df_cal['res'])
abline_plot(model_results = model, color = 'black')

# %%
df_cal['res'] = df_cal['pg'] - predictions
plt.hist(df_cal['res'])
plt.title("Histogram for residuals")
# Out:
# Text(0.5, 1.0, 'Histogram for residuals')

# %%
(np.quantile(df_cal['res'], 0.16), np.quantile(df_cal['res'], 0.84))
# Out:
# (-0.20991175310075633, 0.2520672080332587)

# %%
df_cal.loc[df_cal['QSO'] == True]['res'].values[0]
# Out:
# 0.6101155252419517

# %%
"{0}/{0}.txt".format("R3170")
# Out:
# 'R3170/R3170.txt'

# %%
file1 = open("{}/{}.txt".format("R3170"), "w") 
file1.write("\n------------------QSO {}-------------------\n".format(1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-3c7c10da5ca2> in <module>
# ----> 1 file1 = open("{}/{}.txt".format("R3170"), "w")
#       2 file1.write("\n------------------QSO {}-------------------\n".format(1))
#
# IndexError: tuple index out of range

# %%
df_cal.iloc[2]
# Out:
# ra                 258.823
# dec                43.6864
# u                  19.2767
# g                  18.9542
# r                  18.8725
# i                   18.874
# z                  18.7194
# CentroidRA         258.823
# CentroidDec        43.6865
# Magnitude           9.5694
# diff           7.17274e-05
# pg                  18.601
# QSO                   True
# res               0.610116
# Name: 71, dtype: object

# %%
df_cal['res']
# Out:
# 19     -0.207458
# 28     -0.079965
# 71      0.610116
# 87      0.358675
# 90     -0.210014
#           ...
# 2286   -0.094085
# 2291    0.351290
# 2324    0.199430
# 2336    0.484400
# 2355    0.152846
# Name: res, Length: 145, dtype: float64

# %%
from scipy.stats import sem, t
from scipy import mean
confidence = 0.95
data = list(df_cal['res'])

n = len(data)
m = mean(data)
std_err = sem(data)
h = std_err * t.ppf((1 + confidence) / 2, n - 1)

print(m-h, m+h)
# Out:
# -0.044973327244233564 0.04497332724424003
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#   import sys

# %%
import statsmodels.stats.api as sm
sm.DescrStatsW(res_qso1).tconfint_mean(alpha=0.05)
# Out:
# (-0.04497332724423357, 0.04497332724424004)

# %%
df_cal[df_cal['QSO'] == True]
# Out:
#             ra        dec         u         g         r         i         z  \
# 71  258.822909  43.686418  19.27667  18.95424  18.87252  18.87396  18.71936
#
#     CentroidRA  CentroidDec  Magnitude      diff    del_ra   del_dec  \
# 71  258.822886    43.686486     9.5694  0.000072 -0.081383  0.245058
#
#            pg   QSO       res
# 71  18.600969  True  0.610116

# %%
import numpy as np, scipy.stats as st
a = df_cal['res']
st.t.interval(0.95, len(a)-1, loc=np.mean(a), scale=st.sem(a))
# Out:
# (-0.044973327244233564, 0.04497332724424003)

# %%
from scipy.stats import sem, t
sem(df_cal['res'])
# Out:
# 0.02275315925105658

# %%
#qso2
qso1_ra = df_qso.iloc[1]['ra']
qso1_dec = df_qso.iloc[1]['dec']
qso1_pg = df_qso.iloc[1]['pg']
qso1_mag = df_qso.iloc[1]['Magnitude']

# %%
boxsize = 0.3
df_cal = df_[(df_['ra'] <= qso1_ra + boxsize)&(df_['ra'] >= qso1_ra - boxsize)\
            &(df_['dec'] <= qso1_dec + boxsize)&(df_['dec'] >= qso1_dec - boxsize)
            &(df_['pg'] <= qso1_pg + 1)&(df_['pg'] >= qso1_pg - 2)].copy()
df_cal = df_cal.dropna(subset=['pg', 'Magnitude'])
len(df_cal)
# Out:
# 104

# %%
plt.figure(figsize = (10,10))
plt.scatter(df_cal['Magnitude'], df_cal['pg'], color = 'black', s = 15, alpha = 0.7)
plt.scatter([qso1_mag], [qso1_pg], color = 'red')
plt.title("Magnitude for Plate R3107")
plt.xlabel("APT mag")
plt.ylabel("pg")
# Out:
# Text(0, 0.5, 'pg')

# %%
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import abline_plot

X = df_cal['Magnitude']
X = sm.add_constant(X)
y = df_cal['pg']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     pg   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.412
# Method:                 Least Squares   F-statistic:                     73.04
# Date:                Sat, 23 May 2020   Prob (F-statistic):           1.32e-13
# Time:                        11:36:12   Log-Likelihood:                -35.150
# No. Observations:                 104   AIC:                             74.30
# Df Residuals:                     102   BIC:                             79.59
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.3084      0.819     12.593      0.000       8.685      11.932
# Magnitude      0.7257      0.085      8.546      0.000       0.557       0.894
# ==============================================================================
# Omnibus:                       26.383   Durbin-Watson:                   1.588
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.265
# Skew:                           1.181   Prob(JB):                     2.98e-09
# Kurtosis:                       4.866   Cond. No.                         237.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = abline_plot(model_results = model, color = 'black')
ax = fig.axes[0]
ax.scatter(df_cal['Magnitude'], df_cal['pg'])
ax.scatter([qso1_mag], [qso1_pg], color = 'red')

plt.title("Linear fit for calibration stars Plate R3107")
plt.xlabel("APT mag")
plt.ylabel("pg")
# Out:
# Text(20.625, 0.5, 'pg')

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, "Magnitude", fig=fig)

# %%
df_cal['res'] = df_cal['pg'] - predictions
plt.hist(df_cal['res'])
plt.title("Histogram for residuals")
# Out:
# Text(0.5, 1.0, 'Histogram for residuals')

# %%
import statsmodels.stats.api as sm
sm.DescrStatsW(res_qso1).tconfint_mean(alpha=0.05)
# Out:
# (-0.04497332724423357, 0.04497332724424004)

# %%
df_cal[df_cal['QSO'] == True]
# Out:
#               ra        dec         u         g        r         i         z  \
# 1330  257.855105  43.869076  19.03108  19.11633  19.1446  18.64607  18.69771
#
#       CentroidRA  CentroidDec  Magnitude      diff    del_ra   del_dec  \
# 1330   257.85467    43.868875    10.4625  0.000479 -1.565208 -0.722843
#
#              pg   QSO       res
# 1330  18.640755  True  0.739619

# %%
import numpy as np, scipy.stats as st
a = df_cal['res']
st.t.interval(0.95, len(a)-1, loc=np.mean(a), scale=st.sem(a))
# Out:
# (-0.044973327244233564, 0.04497332724424003)

# %%
from scipy.stats import sem, t
sem(df_cal['res'])
# Out:
# 0.02275315925105658

# %% [markdown]
# ## Effects of radial distance

# %%
df = pd.read_csv("R3170/R3170_match.csv")

# %%
meanra = np.mean(df.ra)
meandec = np.mean(df.dec)

# %%
df['radial_dist'] = np.sqrt((df.ra - meanra)**2 + (df.dec - meandec)**2)*60 #acrmin

# %%
plt.scatter(df['radial_dist'], df['diff'])

# %%
diff_lim = 0.001
df_clean = df[df['diff'] <= diff_lim].copy()
df_clean['pg'] = df_clean['g'] + 0.3*(df_clean['u'] - df_clean['g']) - 0.45

# %%
#import statsmodels.api as sm
#from statsmodels.graphics.regressionplots import abline_plot
df_clean = df_clean.dropna(subset=['pg', 'Magnitude'])
X = df_clean['Magnitude']
X = sm.add_constant(X)
y = df_clean['pg']
model = sm.OLS(y, X).fit()
df_clean['pred_pg'] = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     pg   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                 1.407e+04
# Date:                Sun, 31 May 2020   Prob (F-statistic):               0.00
# Time:                        22:56:37   Log-Likelihood:                -1402.1
# No. Observations:                2376   AIC:                             2808.
# Df Residuals:                    2374   BIC:                             2820.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.6124      0.088     75.064      0.000       6.440       6.785
# Magnitude      1.1494      0.010    118.623      0.000       1.130       1.168
# ==============================================================================
# Omnibus:                     1034.610   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            74226.907
# Skew:                          -1.189   Prob(JB):                         0.00
# Kurtosis:                      30.278   Cond. No.                         90.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.scatter(df_clean['radial_dist'], df_clean['pg'] - df_clean['pred_pg'])

# %%
#import statsmodels.api as sm
#from statsmodels.graphics.regressionplots import abline_plot
df_clean = df_clean.dropna(subset=['pg', 'Magnitude'])
X = df_clean['radial_dist']
X = sm.add_constant(X)
y = df_clean['pg'] - df_clean['pred_pg']
model = sm.OLS(y, X).fit()
df_clean['pg_cor_by_rad'] = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.252
# Model:                            OLS   Adj. R-squared:                  0.252
# Method:                 Least Squares   F-statistic:                     800.1
# Date:                Sun, 31 May 2020   Prob (F-statistic):          6.18e-152
# Time:                        23:00:08   Log-Likelihood:                -1057.1
# No. Observations:                2376   AIC:                             2118.
# Df Residuals:                    2374   BIC:                             2130.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.5077      0.020     25.969      0.000       0.469       0.546
# radial_dist    -0.0143      0.001    -28.285      0.000      -0.015      -0.013
# ==============================================================================
# Omnibus:                     1321.334   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           211335.125
# Skew:                          -1.571   Prob(JB):                         0.00
# Kurtosis:                      49.096   Cond. No.                         97.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.scatter(df_clean['radial_dist'], df_clean['pred_pg'] + df_clean['pg_cor_by_rad'])

# %%
plt.scatter(df_clean['radial_dist'], (df_clean['pred_pg'] + df_clean['pg_cor_by_rad']) - df_clean['pg'])

# %% [markdown]
# ## Query for calibration stars in SDSS (manual version)

# %% [markdown]
# ##### Query used to find calibration stars in this field:
# select ra, dec, u, g, r, i, z, modelmagerr_u, modelmagerr_g,
# modelmagerr_r, modelmagerr_i, modelmagerr_z
#
# from star
#
# where (ra between 257.5 and 260.0) and (dec between 42.75 and 44.75)  and
# modelmag_g < 21.0 and clean = 1

# %%
import pandas as pd

# %%
cal = pd.read_csv("starmatch/R3170/R3170_cal.csv", skiprows=1)

# %%
cal
# Out:
#                ra        dec         u         g         r         i  \
# 0      257.601958  43.846779  21.02859  19.37385  18.57005  18.23596
# 1      257.656208  43.879545  19.76678  18.48773  18.02563  17.87258
# 2      257.539991  43.877754  21.84438  19.27183  17.90633  17.18915
# 3      257.605856  43.931044  19.62954  17.63739  16.86649  16.56941
# 4      257.527278  43.923812  22.68600  20.21087  19.00655  18.48268
# ...           ...        ...       ...       ...       ...       ...
# 15587  259.988455  44.009039  18.42010  17.17168  16.70322  16.54759
# 15588  259.976804  43.840368  18.30698  17.02498  16.57518  16.43489
# 15589  259.992061  43.922334  18.13978  17.12185  16.77095  16.75656
# 15590  259.999252  43.877324  18.76302  17.42209  16.89761  16.73048
# 15591  259.996040  43.826339  17.70297  16.10488  15.49093  15.29389
#
#               z  modelmagerr_u  modelmagerr_g  modelmagerr_r  modelmagerr_i  \
# 0      18.01619       0.085561       0.010881       0.008572       0.008546
# 1      17.82726       0.036282       0.007191       0.006880       0.007315
# 2      16.82446       0.158271       0.010358       0.006630       0.005831
# 3      16.41286       0.033184       0.005402       0.005052       0.004978
# 4      18.24481       0.314642       0.017629       0.010544       0.009668
# ...         ...            ...            ...            ...            ...
# 15587  16.48762       0.015448       0.005387       0.004709       0.005456
# 15588  16.40039       0.014725       0.005269       0.004490       0.005280
# 15589  16.67050       0.013561       0.005271       0.004687       0.005335
# 15590  16.67255       0.018615       0.005635       0.004797       0.005582
# 15591  15.23204       0.011009       0.004730       0.003918       0.004818
#
#        modelmagerr_z
# 0           0.021753
# 1           0.019296
# 2           0.010596
# 3           0.008656
# 4           0.025595
# ...              ...
# 15587       0.008379
# 15588       0.008076
# 15589       0.008986
# 15590       0.008963
# 15591       0.005882
#
# [15592 rows x 12 columns]

# %%
#do this from python
from astroquery.sdss import SDSS
from astropy import coordinates as coords

# %% [markdown]
# ## Query for QSO in SDSS

# %% [markdown]
# ##### Query used for QSO in this field:
# select p.ra, p.dec, s.z, snMedian, p.u, p.g, p.r, p.i, p.z, p.modelmagerr_u, p.modelmagerr_g,
# p.modelmagerr_r, p.modelmagerr_i, p.modelmagerr_z
#
# from photoobj as p, specobj as s
#
# where p.specobjid = s.specobjid and snMedian > 7.0 and s.class = 'QSO'
# and (p.ra between 257.5 and 260.0) and (p.dec between 42.75 and 44.75)

# %%
qso = pd.read_csv("starmatch/R3170/R3170_QSO.csv", skiprows=1)

# %%
qso
# Out:
#             ra        dec         z   snMedian         u         g         r  \
# 0   258.822909  43.686418  2.421538  16.707820  19.27667  18.95424  18.87252
# 1   258.363740  44.370968  2.608278  16.485430  20.16723  18.75215  18.62946
# 2   258.913649  43.412356  0.782486   8.419252  20.77716  19.82656  19.54265
# 3   257.731946  42.886099  1.086822   9.131435  19.72837  19.60237  19.35447
# 4   258.240411  43.122332  1.160563  22.291000  18.72164  18.66474  18.52683
# 5   257.734048  42.802318  0.815241   9.663289  19.20997  18.89720  18.81041
# 6   258.002519  43.495556  1.458988  10.702320  19.33221  19.28545  19.04951
# 7   257.749153  43.126178  1.914229   9.714561  20.29676  20.27546  20.37876
# 8   257.768843  42.783808  1.873098   7.634579  20.82107  20.64220  20.50129
# 9   258.694431  42.821437  2.292792   7.651306  20.88832  19.95499  19.81912
# 10  257.849558  43.810510  1.849336  18.426040  19.51400  19.06775  18.84410
# 11  257.855105  43.869076  1.835150  17.670810  19.03108  19.11633  19.14460
# 12  257.597840  43.858105  2.222425   9.642319  20.35971  19.73818  19.57499
# 13  258.761381  42.757229  1.990197   7.165378  20.65500  20.46758  20.39445
# 14  258.752531  42.911042  1.518372  16.357010  20.06958  19.80941  19.68229
# 15  258.760293  42.979302  0.492497  17.864340  19.28883  18.95293  18.93134
# 16  258.565944  42.950290  1.655799   8.212257  21.09580  20.60810  20.47691
# 17  258.574547  43.123352  1.128165   9.225432  19.41692  19.47366  19.36143
# 18  258.296766  42.865187  0.961274  13.616540  19.89491  19.79166  19.54164
# 19  258.279888  42.793275  0.832063  14.948480  20.60449  19.68328  19.30558
# 20  258.274531  42.883253  0.676228   8.904390  20.37842  19.74250  19.79959
# 21  258.938441  42.849489  1.413850  10.793140  19.73658  19.62711  19.25437
# 22  258.878080  43.123283  0.371367  10.687330  19.96689  19.68393  19.39991
# 23  257.944752  44.585979  2.431609   7.572589  21.51470  20.78963  20.56559
# 24  258.380959  43.615693  0.167522  16.544330  19.09932  18.51762  17.74844
# 25  258.011592  44.226969  0.873712  15.878890  19.44558  19.11290  19.09152
# 26  257.932799  44.018795  2.958854  11.247930  21.11211  19.35677  19.09321
#
#            i        z1  modelmagerr_u  modelmagerr_g  modelmagerr_r  \
# 0   18.87396  18.71936       0.023274       0.009167       0.009716
# 1   18.42419  18.02144       0.039606       0.008181       0.008705
# 2   19.47729  19.14109       0.058187       0.014286       0.014299
# 3   19.37905  19.41620       0.033607       0.013398       0.013753
# 4   18.49721  18.48767       0.019436       0.007765       0.008420
# 5   18.93487  18.85936       0.024563       0.008866       0.009823
# 6   18.90976  18.99333       0.024217       0.010542       0.010842
# 7   19.82082  19.71232       0.049697       0.020005       0.029299
# 8   20.20028  20.14550       0.071943       0.026949       0.031036
# 9   19.66104  19.39292       0.068128       0.015394       0.016365
# 10  18.41751  18.23020       0.028057       0.009445       0.009913
# 11  18.64607  18.69771       0.021498       0.009682       0.011542
# 12  19.43377  19.20350       0.052943       0.013223       0.014466
# 13  20.26538  20.12969       0.058078       0.021246       0.024001
# 14  19.47465  19.45462       0.039329       0.014195       0.015248
# 15  18.79914  18.80589       0.024867       0.009128       0.009984
# 16  20.09227  20.02962       0.079399       0.022928       0.025732
# 17  19.35394  19.42212       0.027086       0.011953       0.012761
# 18  19.62292  19.52682       0.038863       0.013581       0.014420
# 19  19.23006  19.04952       0.061012       0.012795       0.012352
# 20  19.62112  19.63527       0.053253       0.013237       0.016749
# 21  19.08682  19.06163       0.035514       0.013428       0.013131
# 22  19.27357  19.01571       0.040937       0.014240       0.014909
# 23  20.66069  20.20154       0.098731       0.023508       0.026726
# 24  17.29634  17.01645       0.029957       0.009103       0.006724
# 25  19.26641  19.09541       0.026914       0.009541       0.010986
# 26  18.96261  18.96465       0.082608       0.011165       0.011039
#
#     modelmagerr_i  modelmagerr_z
# 0        0.012224       0.030149
# 1        0.009651       0.019685
# 2        0.019598       0.054579
# 3        0.016021       0.054806
# 4        0.009448       0.029767
# 5        0.012118       0.035591
# 6        0.013225       0.048202
# 7        0.026688       0.084616
# 8        0.029170       0.100482
# 9        0.020176       0.050959
# 10       0.010026       0.024453
# 11       0.011385       0.034726
# 12       0.016836       0.053570
# 13       0.031145       0.092897
# 14       0.018208       0.055135
# 15       0.011957       0.033217
# 16       0.027596       0.086791
# 17       0.016898       0.053226
# 18       0.018565       0.068534
# 19       0.014272       0.045889
# 20       0.018511       0.075411
# 21       0.016297       0.047611
# 22       0.019433       0.048527
# 23       0.038750       0.099715
# 24       0.006656       0.015330
# 25       0.015879       0.047488
# 26       0.012585       0.036504
